# %%
import requests
from requests.exceptions import RequestException
# from multiprocessing import Pool
import re
from bs4 import BeautifulSoup
import jieba
import wordcloud
import collections

print('Libraries imported')
# Out:
# Libraries imported

# %%
url_list = []

a = 0
while a != 70:
    a += 1
    for b in range(1,40):
        urls = 'https://mojim.com/cny100012x{}x{}.htm'.format(a,b)
        url_list.append(urls)

# %%
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'}
lyrics = []
for each_item in url_list:
    response = requests.get(each_item, headers=headers).text
    try:
        if response != '\ufeff\ufeff\ufefferror':
            soup = BeautifulSoup(response, features='lxml')
            text = [item.get_text(strip=True) for item in soup.select('dd.fsZx3')][0]
            pattern = re.sub(r'\[.*','',text).replace('更多更详尽歌词 在※ Mojim.com　魔镜歌词网','').replace('\u3000','').strip()
            lyrics.append(pattern)

            song = [item.get_text(strip=True) for item in soup.select('dt.fsZx2')][0]        
            file = song+'.txt'
            f=open(file,'w')
            f.write(pattern)
            f.close()
            print(song)
        else:
            pass
    except:
        FileNotFoundError
# Out:
# 疯狂世界
# 拥抱
# 透露
# 生活
# 爱情的模样
# 嘿我要走了
# 轧车
# 志明与春娇
# HoSee
# 黑白讲
# I Love You 无望
# 风若吹
# 为什么
# 终结孤单
# 明白
# 心中无别人
# 有你的将来
# 憨人
# 叫我第一名
# 雨眠
# 罗密欧与茱丽叶
# 温柔
# 爱情万岁
# 反而
# 黑白讲
# 轧车
# Ho See
# Talk
# I Love You 无望
# 风若吹
# 生活
# 就在今夜
# 爱情酿的酒
# 拥抱
# 疯狂世界
# 轧新车
# 志明与春娇(不插电版本)
# 爱情的模样
# 透露
# 志明与春娇(Encore)
# 叫我第一名
# 轧车
# Ho See
# 黑白讲
# 风若吹
# 为什么
# I LOVE YOU无望
# 拥抱
# 明白(前段)
# 明白(后段)
# 有你的将来
# 雨眠
# 罗密欧与茱丽叶
# 温柔
# 爱情万岁
# 爱情的模样
# 摇滚舞台
# 终结孤单
# 嘿我要走了
# 透露
# 生活
# 反而
# 心中无别人
# 憨人
# 志明与春娇
# 疯狂世界
# 左键
# 公路电影
# 年华
# 罗密欧与茱丽叶
# 侯鸟
# 一颗苹果
# 能不能不要说
# 好不好
# 相信
# Ok La(Ok啦)
# 借问众神明
# 永远的永远
# 彩虹
# 啾啾啾
# 纯真
# 候鸟
# 人生海海
# Intro
# 疯狂世界(钢琴版)
# 终结孤单(live2001)
# 透露
# 能不能不要说
# 轧车
# 风若吹
# 纯真
# 彩虹
# 好不好
# 志明与春娇
# 啾啾啾
# 爱情万岁
# Ho See
# 叫我第一名
# 为什么
# 借问众神明
# 一颗苹果
# 拥抱
# 爱情的模样(拥抱)
# 温柔
# 天天想你(+石头求婚)
# 永远的永远
# I LOVE YOU无望
# 心中无别人(live2001)
# I'm in love
# 我爱夏天
# Ok啦
# 候鸟(live 2001)
# 人生海海
# 明白(歌迷版)
# 憨人
# 相信
# 疯狂世界
# 嘿我要走了
# 王子面
# 东海小王子
# 虚弱
# 八月爱人
# 金色大街
# 雌雄同体
# 从这里开始(乐团国歌)
# 谁忘了爱我
# I Can Fly
# 我(总统的书送的)
# 摇滚本事
# 生命有一种绝对
# 我
# 闯(永远的永远国语版)
# 终结孤单
# 温柔
# 疯狂世界
# 拥抱
# 彩虹
# 爱情的模样
# 在这一秒
# 摇滚本事
# 人生海海
# 生命有一种绝对
# 爱情万岁
# 透露
# 我
# 闯
# 武装
# 轻功
# 恒星的恒心
# 雌雄同体
# 阿姆斯壮
# 而我知道
# 赌神
# 别惹我
# 九号球
# 武装
# 时光机
# 我们(时时刻刻)
# 在这一秒
# 生命有一种绝对
# 王子面
# 小时候
# 阿姆斯壮
# 92全运会纪念演奏曲
# 92全运会开幕表演音乐(跃动北县篇)
# 92全运会闭幕表演音乐(活力E时代篇)
# 阿姆斯壮(演奏曲)
# 听不到
# 听不到(Kala版)
# Intro
# 武装
# 摇滚本事
# 疯狂世界
# 终结孤单
# 透露
# 拥抱
# Talking
# 相信(live 2003)
# 轻功
# 向前走
# 好不好
# I LOVE YOU无望
# 我
# 人生海海
# OK啦
# 叫我第一名
# 王子面
# 雌雄同体
# 爱情万岁
# 生命有一种绝对
# 温柔
# 心中无别人
# 轧车
# 志明与春娇
# Talking
# 憨人
# 探母
# 寂寞星球
# 温柔(还你自由版)
# 轻功(京片子版)
# 轻功(甜蜜碎拍Remix)
# 武装
# 那一年的花季(探母萱萱版)
# 恒星的恒心(下定决心版)
# 而我知道
# 疯狂世界
# 纯真
# 生命有一种绝对(绝对String Mix版)
# 时光机
# 五月之恋序曲
# 纯真(演奏曲)
# 轻功(京片子版配乐)
# 探母(配乐)
# 三城记
# 如果我是石头
# 青岛巴士
# 寻根(带我去三义)
# 诚品激突
# 武装以后(演奏曲)
# 那一年的花季(探母瑄瑄版配乐)
# 灵魂能有多重
# 哪一楼的阿?(台北的脚步)
# 三义之夏
# 轻功(慢摇滚演奏版)
# 而我知道(冰融演奏版)
# 寂寞星球人人寂寞
# 故事都随风(开往哈尔滨的列车)
# 爱是绿洲
# 寂寞星球(电影版)
# 孙悟空
# 倔强
# 垃圾车
# 小护士
# 让我照顾你
# 约翰蓝侬
# 回来吧
# 错错错
# 晚安地球人
# 超人
# 神的孩子都在跳舞(Instrumental)
# 圣诞夜惊魂
# 垃圾车(朋友版)
# 录音偷窥全都录(Life Recording Of 2004)
# Enrich Your Life
# Intro
# 孙悟空+放手
# 终结孤单
# 圣诞夜惊魂
# Ok啦
# 叫我第一名
# Talking of mayday
# 燕尾蝶
# 爱情万岁+脱掉
# 时光机
# 轻功
# 赌神
# 恒星的恒心
# I Love You无望
# 武装
# 一颗苹果
# 而我知道
# 回来吧
# 超人
# 疯狂世界
# HoSee
# Tears For Fears
# The Heart Beat Of反击
# 晚安地球人
# 这个世界
# 拥抱+相信
# 神的孩子都混在一起
# 小护士
# 人生海海
# Enrich Your Life让我照顾你
# 心中无别人
# 约翰蓝侬
# 垃圾车(朋友版)
# 憨人
# 轧车
# 志明与春娇
# 温柔(还你自由版)
# 倔强
# 花(音乐来自四方-特别收录)
# 花(预购版)
# 花(音乐来自四方)
# 知足
# 牙关
# 乱世浮生
# 恋爱ing
# 听不到
# 拥抱
# 终结孤单
# 而我知道
# 孙悟空
# 人生海海
# 疯狂世界
# 爱情万岁
# 恒星的恒心
# 温柔(还你自由版)
# 倔强
# 金多虾
# 麦来乱
# 志明与春娇
# 心中无别人
# 好不好
# 憨人
# OK啦
# 垃圾车 (朋友版)
# 叫我第一名
# 轧车
# I Love You 无望
# 永远的永远
# 借问众神明
# 未来 (Sailing，With Me)
# Happy Birth Day
# Do you ever shine(国语版)
# 勇敢(国语版)
# 出头天-五月天
# 开天窗
# 走火入魔
# 花火(&丁当)
# OAOA
# 2010 离开地球表面(花漾嘉年华版)
# 憨人2010出头天版
# 超级偶像
# OAOA feat. Ryuta Yamamura(flumpool)
# 疼爱
# 干啦干啦 Cheers！
# 笨小孩
# MADE IN HEAVEN
# 伤心的人就听撑腰
# 前传
# 为爱而生
# 天使
# 我又初恋了
# 香水
# 摩托车日记
# 最重要的小事
# 快乐很伟大
# 忘词
# 宠上天
# 米老鼠
# 一千个世纪
# 胎音
# 私奔到月球
# 离开地球表面
# to find my paradise
# 抓狂
# 知足
# 垃圾车(07'最够朋友版)
# 天使
# 摩托车日记
# 孙悟空(天堂的五个朋友02)
# 阿姆斯壮(天堂的五个朋友03)
# 约翰蓝侬(天堂的五个朋友04)
# 我又初恋了(内地版加收录)
# 我(天堂的五个朋友05)
# 玛莎的小事(Ot最重要的小事)
# 最重要的小事
# 晚安地球人+疯狂世界
# paradise+倔强
# 离开地球表面(remix by DJ ROCK)
# 年轻就要对味(中国版 加收录)
# 盛夏光年
# 秒杀(FEATING.ENERGY)
# 小太阳
# 笑忘歌【黑松沙士】广告歌曲
# 突然好想你
# 生存以上 生活以下
# 你不是真正的快乐
# 爆肝
# 噢买尬
# 出头天
# 我心中尚未崩坏的地方
# 春天的呐喊
# 夜访吸血鬼
# 如烟
# 后青春期的诗
# 笑忘歌
# 放肆
# DNA
# 轧车
# 爆肝
# 赌神
# HoSee
# 你不是真正的快乐
# 生存以上生活以下
# 疯狂世界+候鸟
# 一颗苹果
# 我心中尚未崩坏的地方
# 知足
# 人生海海
# 春天的呐喊
# 离开地球表面
# DNA
# 笑忘歌
# 如烟
# 孙悟空 Ver. All Crew Out
# 约翰蓝侬+我
# 最重要的小事
# 天使
# 起来
# 放肆
# 突然好想你
# 温柔
# 志明与春娇
# 出头天+憨人
# 小太阳
# 年轻就要对味
# happy.BIRTH.day
# 金色大街
# 咸鱼
# 不见不散
# ENRICH YOUR LIFE 让我照顾你
# 八月爱人
# 花
# 虚弱
# 盛夏光年
# First Day
# OAOA
# 咖哩鱼蛋(TO:离开地球表面)(王汤尼)
# 恋爱ing(3DNA追梦版)(高媛媛)
# 知足(3DNA 追梦版)(家家)
# 倔强(3DNA 追梦版)(家家)
# OAOA (3DNA追梦版)(家家)
# DNA(3DNA LIVE 版)
# 离开地球表面(3DNA LIVE 版)
# 最重要的小事 (3DNA LIVE 版)
# 恋爱ing(3DNA LIVE 版)
# 你不是真正的快乐(3DNA LIVE 版)
# 突然好想你(3DNA LIVE 版)
# 温柔 还你自由版 (3DNA LIVE 版)
# 知足(3DNA LIVE 版)
# 天使(3DNA LIVE 版)
# 倔强(3DNA LIVE 版)
# 我心中尚未崩坏的地方(3DNA LIVE 版)
# 星空
# 2012
# 仓颉
# 洗衣机
# 歪腰
# 干杯
# 我不愿 让你一个人
# 星空
# 三个傻瓜
# 末日
# OAOA(丢掉名字性别)
# 第二人生
# 诺亚方舟
# 有些事现在不做 一辈子都不会做了
# T 121 3121(hidden track)
# OAOA(现在就是永远)
# 我不愿让你一个人
# 伤心的人别听慢歌(贯彻快乐)
# 入阵曲
# 步步
# Dancin' Dancin'feat.TERU(GLAY)
# Belief ～春を待つ君へ～
# 満ち足りた想い出(知足)
# 出阵の歌(入阵曲 )
# 一歩一歩(歩歩)
# 仆は仆に嘘をつかない(倔强)
# 爱の记忆は突然に(突然好想你)
# 恋爱ING(恋爱ING)
# 干杯
# 孙悟空
# 瞬间少年ジャンプ(离开地球表面)
# 君は幸せじゃないのに(你不是真正的快乐)
# ひとり上手にならないで(我不愿让你一个人)
# OAOA(日文版)
# やさしすぎて(温柔)
# 坚强虚幻
# Belief ～给等待春天的你～
# brilliant days
# BONUS TRACK
# 有些事现在不做一辈子都不会做了(启航版)(LIVE版)
# 2012(LIVE版)
# 叫我第一名(LIVE版)
# 爱情万岁(LIVE版)
# 星空(LIVE版)
# 我不愿让你一个人(LIVE版)
# 仓颉(LIVE版)
# 你不是真正的快乐(LIVE版)
# 盛夏光年(LIVE版)
# 诺亚方舟(LIVE版)
# 一千个世纪(LIVE版)
# 如烟+如果还有明天(LIVE版)
# 拥抱(LIVE版)
# 第二人生(LIVE版)
# 干杯(LIVE版)
# 疯狂世界(LIVE版)
# 三个傻瓜(LIVE版)
# OK啦(LIVE版)
# 温柔(LIVE版)
# OAOA(现在就是永远)(LIVE版)
# 有些事现在不做一辈子都不会做了(LIVE版)
# 倔强(LIVE版)
# 离开地球表面+诺亚方舟(LIVE版)
# 突然好想你(LIVE版)
# 憨人(LIVE版)
# 伤心的人别听慢歌(贯彻快乐)(特别收录)
# 步步
# 拥抱(2013新录制作品)
# 伤心的人别听慢歌(贯彻快乐)
# 洋葱(2013新录制作品)
# 干杯
# 入阵曲
# 倔强
# 突然好想你
# 恋爱ing
# 离开地球表面
# 星空
# 我不愿让你一个人
# 人生海海
# 知足
# 温柔
# 你是唯一(2013新录制作品)
# 夜访吸血鬼
# 如烟
# 盛夏光年(2013新录制作品)
# 一颗苹果
# 三个傻瓜
# 孙悟空
# 摩托车日记
# 最重要的小事
# 爱情万岁
# 雌雄同体
# 生命有一种绝对
# 诺亚方舟
# 我心中尚未崩坏的地方
# 憨人
# Do You Ever Shine?
# 抱きしめて(拥抱 日本语ver.)
# OAOA (日本语ver.)
# DNA
# ノアの方舟
# Do You Ever Shine? (BITTER BLOOD ver.)
# 由我们主宰
# 九号球(2014全新录音)
# 将军令
# 盛夏光年(剧情版)
# YOUR LEGEND ～燃ゆる命～ (将军令 日本语ver.)
# 追忆のナインボール (九号球 日本语ver.)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-8186d9f9ae4e> in <module>
#      12         song = [item.get_text(strip=True) for item in soup.select('dt.fsZx2')][0]
#      13         file = song+'.txt'
# ---> 14         f=open(file,'w')
#      15         f.write(pattern)
#      16         f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '青春の彼方/盛夏光年.txt'

# %%
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'}
lyricsplus = []
for each_item in url_list[1952:]:
    responseplus = requests.get(each_item, headers=headers).text
    try:
        if responseplus != '\ufeff\ufeff\ufefferror':
            soupplus = BeautifulSoup(responseplus, features='lxml')
            textplus = [item.get_text(strip=True) for item in soupplus.select('dd.fsZx3')][0]
            patternplus = re.sub(r'\[.*','',textplus).replace('更多更详尽歌词 在※ Mojim.com　魔镜歌词网','').replace('\u3000','').strip()
            lyricsplus.append(patternplus)

            songplus = [item.get_text(strip=True) for item in soupplus.select('dt.fsZx2')][0]        
            file = songplus+'.txt'
            f=open(file,'w')
            f.write(patternplus)
            f.close()
            print(songplus)
        else:
            pass    
    except:
        FileNotFoundError
# Out:
# 星空
# 将军令(オリジナルver.)
# 九号球(オリジナルver.)
# 勇敢 (Braveness)
# 温柔(2016)
# 如果我们不曾相遇
# 成名在望
# 好好(想把你写成一首歌)
# 兄弟
# 人生有限公司
# 后来的我们
# 顽固
# 派对动物
# 最好的一天
# 少年他的奇幻漂流
# 终于结束的起点
# 任意门
# 转眼
# what's your story?
# 你说那 C 和弦就是...
# 素敌だから(君を歌にしたい)
# what's your story?
# Cコードは...
# Song for you
# Buzzin'
# YOUR LEGEND 〜燃ゆる命〜(将军令 日本语ver.)
# Do You Ever Shine?
# 凡人歌(& 萧敬腾)
# 成名在望
# 志明与春娇 (国语版)
# 任意门(五人轮唱版)
# 什么歌
# 后来的我们(眼泪未干版)
# I Will Carry You
# 当每颗星星
# 转眼(2018 自传最终章)
# 一半人生
# 有些事现在不做一辈子都不会做了
# 我不愿让你一个人
# 星空
# 洗衣机
# 三个傻瓜
# 歪腰
# 干杯
# 仓颉
# 2012
# 第二人生
# 诺亚方舟
# 明日
# OAOA(现在就是永远)
# T 121 3121
# 隐形的纪念
# 纯真 #MaydayBlue20th

# %%
print(len(lyrics))
# Out:
# 610

# %%
lyrics_string = ''.join(lyrics)

# %%
seg_lists = [word for word in jieba.cut(lyrics_string, cut_all=False) if len(word)>=2]
# print("Default Mode: " + "/ ".join(seg_lists))  # 精确模式
print(seg_lists)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/zs/d9gz6bhs4dq50vplx33c0rlw0000gn/T/jieba.cache
# Loading model cost 1.285 seconds.
# Prefix dict has been built succesfully.
# ['作词', '阿信', '作曲', '阿信', '编曲', '五月天', '如果说', '后悔', '是不是', '一切', '倒退', '回忆', '多么', '活着', '多么', '狼狈', '为什么', '这个', '世界', '总要', '伤悲', '不能', '了解', '不想', '了解', '逃离', '这个', '疯狂', '世界', '那么', '多苦', '那么', '多累', '那么', '莫名', '泪水', '逃离', '这个', '疯狂', '世界', '如果', '发现', '挽回', '一整夜', '再也', '想不起', '一种', '感觉', '夜晚', '里面', '青春', '转眼', '消失', '指间', '用力', '浪费', '用力', '后悔', '逃离', '这个', '疯狂', '世界', '那么', '多苦', '那么', '多累', '那么', '莫名', '泪水', '逃离', '这个', '疯狂', '世界', '如果', '发现', '挽回', '逃离', '这个', '疯狂', '世界', '那么', '多苦', '那么', '多累', '那么', '莫名', '泪水', '逃离', '这个', '疯狂', '世界', '如果', '发现', '挽回', '逃离', '这个', '疯狂', '世界', '那么', '多苦', '那么', '多累', '那么', '莫名', '伤悲', '逃离', '这个', '疯狂', '世界', '如果', '发现', '挽回', '作词', '阿信', '作曲', '阿信', '编曲', '五月天', '脱下长', '假面', '梦幻', '疆界', '南瓜', '马车', '午夜', '换上', '童话', '玻璃', '享受', '感觉', '孤傲', '蔷薇', '品尝', '滋味', '纷乱', '世界', '了解', '昨天', '太近', '明天', '太远', '默默', '聆听', '黑夜', '晚风', '荷花', '叶任', '醉倒在', '池边', '清楚', '看见', '月光', '晒干', '眼泪', '一个', '人爱', '紧握', '抱紧', '爱别', '隐藏', '自己', '疲倦', '表达', '自己', '狼狈', '放纵', '自己', '狂野', '找寻', '自己', '明天', '要求', '誓言', '就算', '谎言', '需要', '慰藉', '就算', '那爱', '潮水', '作词', '阿信', '作曲', '阿信', '编曲', '五月天', '不知不觉', '不经意', '占有', '心里', '初衷', '我心', '深处', '无处', '透露', '全世界', '寂寞', '即将', '摆脱', '不到', '昨日', '恶梦', '我心', '深处', '扰嚷', '沉默', '不再', '沉默', '天下', '完美', '阵容', '狂飙', '爱意', '突然', '变得', '此刻', '完全', '透露', '眼睛', '双颊', '笑容', '秘密', '星座', '我心', '深处', '建造', '一个', '王国', '到底', '有没有', '发现', '不同', '看着', '真实', '赤裸', '深处', '可否', '接受', '不再', '退缩', '不再', '保留', '透露', '作词', '阿信', '作曲', '阿信', '编曲', '五月天', '有场', '战争', '眼前', '斗志', '斗不过', '温暖', '棉被', '水龙头', '流出', '眼泪', '残酷', '美好', '一天', '眼前', '一千件', '事正', '解决', 'EVERYBODY', '想要', '改变', 'EVERYTHING', 'WONT', 'BE', 'OK', '七点', '一杯', '咖啡', '八点', '红绿灯', '斑马线', 'BUSY', 'GAMEEVERYDAY', '活在', '疯狂', '世界', '活在', '美好', '明天', '重重', '考验', '来到', '今天', '不知不觉', '改变', '远离', '每个', '昨天', '那些', '眼泪', '没有', '时间', '再见', '喜怒哀乐', '苦辣酸甜', '边缘', '徘徊', '终于', '了解', '就是', '生活', '滋味', '生活', '太近', '梦想', '太远', '午餐', '吃饭', '还是', '吃面', '喜欢', '忙碌', '电话', '吵醒', '星期天', '珍惜', '浪费时间', '换来', '生命', '理想', '划过', '天边', '爱情', '擦肩', '分不清', '东南西北', '分不清', 'CRYING', 'GAME', '是不是', '答案', '终点', '后面', '当初', '信念', '现在', '狂奔', '每个', '白天', '寂寞', '每个', '慢慢', '发现', 'SUPERMAN', '作词', '阿信', '作曲', '阿信', '编曲', '五月天', '巨大', '海洋', '身上', '失去', '自己', '形状', '看到', '远方', '爱情', '模样', '曾经', '孤单', '徬徨', '曾经', '相信', '曾经', '失望', '穿过', '重重的', '迷惘', '那爱', '慌张', '终于', '解放', '狂恋', '勇敢', '挑战', '全世界', '一样', '身体', '里面', '一样', '感觉', '无所谓', '没有', '爱情', '界限', '一样', '身体', '里面', '谜样', '魔力', '却是', '强烈', '星星', '夜空', '闪亮', '星空', '不停', '流浪', '此生', '无知', '奔忙', '因为', '眼光', '化成', '光亮', '世界', '全部', '漂亮', '不过', '可爱', '模样', '我举', '双手', '投降', '跨出', '城墙', '长出', '翅膀', 'Repeat', '作词', '阿信', '作曲', '阿信', '编曲', '五月天', '轻轻', '闭上眼睛', '此刻', '觉得', '清醒', '已经', '需要', '一些', '挽留', '字句', '绚烂', '新世纪', '深情', '受欢迎', '那么', '用力', '好像', '一场', '闹剧', '我要', '昨天', '对白', '不再', '重要', '最美', '一幕', '只是', '此刻', '结束', '结束', '不断', '找寻', '然后', '不断', '放弃', '不断', '犯错', '然后', '不断', '远离', '如果', '我爱你', '反正', '自做', '多情', '看家本领', '我要', '昨天', '对白', '重要', '最美', '一幕', '只是', '此刻', '结束', '我要', '昨天', '对白', '重要', '最美', '一幕', '只是', '此刻', '结束', '轻轻', '闭上眼睛', '此刻', '觉得', '清醒', '已经', '需要', '一些', '挽留', '字句', '绚烂', '新世纪', '深情', '受欢迎', '收拾', '行李', '找寻', '自己', '结束', '结束', '...', '结束', '.....', '结束', '.......', '作词', '阿信', '作曲', '阿信', '编曲', '五月天', '怎阿花', '阿娇拢', '无佳意', '撇车', '技术', '一流', '无人', '学校', '老师', '疼痛', '是不是', 'ABCD', '看无卡', '免教', '老爸', '老母', '归工底', '喋喋', '无知', '哪会', '身边', '问题', '一摊', '这时', '阵上', '作阵', '轧车', '作阵来', '轧车', '作阵来', '轧车', '毋管', '警察', '毋管', '父母', '只要', '引擎', '催落', '无人', '可当甲', '最快', '最大', '今日', '观众', '仔逐家', '一个', '亲像', 'Super', 'Star', 'La', 'La', 'LaLa', 'La', 'La', 'La', 'La', 'La', 'La', '愈爽', '唱歌', '头脑', '底飞', '身躯', '风底', '心底', '流汗', '那会', '这爽', '了解', '感觉', '这时', '阵上', '作阵', '轧车', '作词', '阿信', '作曲', '阿信', '编曲', '五月天', '志明', '真正', '不知', '为什么', '爱人', '不愿阁', '相偎', '春娇', '已经', '早就', '听讲', '这多', '其实', '拢总', '无卡', '抓走', '淡水', '海岸', '两个', '爱情', '已经', '无人', '已经', '无人', '最好', '已经', '感觉', '冻止', '免爱', '最好', '已经', '感觉', '麦阁', '伤心', '麦阁', ' ...

# %%
import collections

# %%
c = collections.Counter(seg_lists)
for word_freq in c.most_common(50):
    word, freq = word_freq
    print(word, freq)
# Out:
# 阿信 912
# 作曲 563
# 作词 539
# 世界 450
# 自己 433
# 我们 418
# 五月天 371
# 一个 338
# 没有 315
# 如果 312
# 编曲 275
# 一天 241
# 快乐 240
# 想要 237
# 那么 235
# 人生 233
# 什么 233
# 不能 227
# 最后 222
# 就是 216
# 永远 196
# 回忆 193
# 为什么 188
# La 188
# 不是 183
# 就算 168
# 真的 167
# 自由 167
# 突然 166
# 知道 166
# 就让 163
# 还是 158
# 不要 155
# 爱情 149
# 怎么 148
# 一次 147
# 孤单 146
# 希望 141
# 眼泪 140
# 可以 137
# 未来 135
# 真正 134
# 开始 131
# 这个 129
# 变成 129
# 不会 129
# 一生 128
# 已经 126
# 温柔 126
# 怪兽 125

# %%
exclude_words = ['五月天','阿信','作曲','作词','编曲','La','HoSee','Repeat','什么','这样','这个',
                 '不是','一天','一个','就是','OK','怪兽','La ','var','OKOK','最新', '单曲','首歌',
                 '曲长', '20', '分钟', 'non', 'stop', 'mix',]

# %%
i = 0
while i != 5:
    for word in seg_lists:
        if word in exclude_words:
            seg_lists.remove(word)
    i +=1

# %%
c = collections.Counter(seg_lists)
for word_freq in c.most_common(50):
    word, freq = word_freq
    print(word, freq)
# Out:
# 世界 450
# 自己 433
# 我们 418
# 没有 315
# 如果 312
# 快乐 240
# 想要 237
# 那么 235
# 人生 233
# 不能 227
# 最后 222
# 永远 196
# 回忆 193
# 为什么 188
# 就算 168
# 真的 167
# 自由 167
# 突然 166
# 知道 166
# 就让 163
# 还是 158
# 不要 155
# 爱情 149
# 怎么 148
# 一次 147
# 孤单 146
# 希望 141
# 眼泪 140
# 可以 137
# 未来 135
# 真正 134
# 开始 131
# 变成 129
# 不会 129
# 一生 128
# 已经 126
# 温柔 126
# 现在 123
# 决定 121
# 等待 121
# 期待 118
# 地球 117
# 只要 114
# 生命 112
# 一样 112
# 感觉 111
# 明天 111
# 不愿 111
# 走过 110
# 天空 109
